# %% [markdown]
# # Conversational Search
#
# In this notebook you will implement the following steps:
#
# - **Retrieval + evaluation**: Implement a *search-based* conversation framework evaluation framework to evaluate conversation topics made up of conversation turns.
# - **Passage ranking**: Implement a *ranking method* to sort the initial search results. Evaluate the re-ranked results.
# - **Conversation tracking**: Implement a *state tracking* method with memory networks to keep track of the conversation.
#
# Submission dates:
# - **20 november**: retrieval + evaluation + passage ranking
# - **20 december**: revised passage ranking + conversation state tracking
#
# ## Test bed and conversation topics
# The MSMARCO corpus (http://www.msmarco.org/dataset.aspx) for Conversational Search is indexed in this cluster and available to be searched behind an ElasticSearch API.
#
# The queries and the relevance judgments are available through class `ConvSearchEvaluation`:

# %%
import TRECCASTeval as trec
import numpy as np

#nao temos resultados para todas as conversas, apenas ~15 estao avaliadas

test_bed = trec.ConvSearchEvaluation()

for topic in test_bed.train_topics:
    conv_id = topic['number']
    
    for turn in topic['turn']:
        turn_id = turn['number']
        utterance = turn['raw_utterance']
        
        print('%d_%d'% (conv_id, turn_id), utterance)
# Out:
# 1_1 What is a physician's assistant?
# 1_2 What are the educational requirements required to become one?
# 1_3 What does it cost?
# 1_4 What's the average starting salary in the UK?
# 1_5 What about in the US?
# 1_6 What school subjects are needed to become a registered nurse?
# 1_7 What is the PA average salary vs an RN?
# 1_8 What the difference between a PA and a nurse practitioner?
# 1_9 Do NPs or PAs make more?
# 1_10 Is a PA above a NP?
# 1_11 What is the fastest way to become a NP?
# 1_12 How much longer does it take to become a doctor after being an NP?
# 2_1 What are the main breeds of goat?
# 2_2 Tell me about boer goats.
# 2_3 What breed is good for meat?
# 2_4 Are angora goats good for it?
# 2_5 What about boer goats?
# 2_6 What are pygmies used for?
# 2_7 What is the best for fiber production?
# 2_8 How long do Angora goats live?
# 2_9 Can you milk them?
# 2_10 How many can you have per acre?
# 2_11 Are they profitable?
# 3_1 Tell me about the types of irregular heart beat.
# 3_2 How serious is an irregular heart beat?
# 3_3 What are the different types of tachycardia?
# 3_4 What is atrial flutter?
# 3_5 What causes it?
# 3_6 What's the difference between flutter and fibrillation?
# 3_7 How does afib affect an ECG?
# 3_8 Does it shorten your life?
# 3_9 What triggers it?
# 3_10 How do you stop an attack?
# 3_11 What is the best exercise for it?
# 4_1 What was the neolithic revolution?
# 4_2 When did it start and end?
# 4_3 Why did it start?
# 4_4 What did the neolithic invent?
# 4_5 What tools were used?
# 4_6 When was it brought to the british isles?
# 4_7 Describe the period that follows it.
# 4_8 What was its significance?
# 4_9 What were the houses like?
# 5_1 What are the best ways to cook a turkey?
# 5_2 Should I brine a turkey before smoking it?
# 5_3 How much salt do I use to brine it?
# 5_4 What kind of wood should I use?
# 5_5 How long should it be smoked for?
# 5_6 Is smoked turkey healthy?
# 5_7 What can you do with leftovers?
# 5_8 How long are leftovers good for in the fridge?
# 5_9 What's a recipe for smoked turkey soup?
# 5_10 How about one for chili?
# 6_1 What are the most important US supreme court cases?
# 6_2 What did Plessy v. Ferguson establish?
# 6_3 How about Marbury vs Madison?
# 6_4 Was it unanimous?
# 6_5 What was the implication of Roe vs Wade?
# 6_6 What were the main arguments?
# 6_7 What was the point of Brown v Board of Ed?
# 6_8 What were the main arguments?
# 6_9 Why is it important today?
# 7_1 What are the different types of macromolecules?
# 7_2 Tell me about the characteristics of carbohydrates.
# 7_3 What are they composed of?
# 7_4 What is their basic structure?
# 7_5 What are the main types with examples of each?
# 7_6 Tell me about lipids.
# 7_7 What is their function?
# 7_8 What are the types of lipids?
# 7_9 What is the most common?
# 7_10 What is the difference between them and carbohydrates?
# 7_11 Why are carbs better?
# 8_1 What was the Securities Act of 1933?
# 8_2 What is exempt from it?
# 8_3 Why was it needed?
# 8_4 What was the reason for creating the 1934 act?
# 8_5 What is the largest securities exchange in the world?
# 8_6 How and when when was it created?
# 8_7 What was the first stock market?
# 9_1 Why is statistics important?
# 9_2 Why should one study it?
# 9_3 Tell me about its career options.
# 9_4 Are Data Scientists in high demand?
# 9_5 How much do they make on average in a year?
# 9_6 What is range in statistics?
# 9_7 Describe some different metrics to interpret it.
# 9_8 What are quartiles?
# 9_9 How do you find the lower and upper quartile?
# 10_1 How does water freeze?
# 10_2 What happens to its molecules?
# 10_3 Why isn't the bottom of the ocean frozen?
# 10_4 Can the bottom of the ocean freeze?
# 10_5 Where is the coldest place on Earth?
# 10_6 Does Dome Fuji have inhabitants?
# 10_7 Why is Antarctica so cold?
# 10_8 How cold is the water underneath the ice?
# 10_9 What is the biggest town?
# 11_1 What are  futuristic designs?
# 11_2 How did this become a new trend?
# 11_3 Why are most of the constructions inspired by these designs?
# 11_4 What are the different domains where such designs have been adapted?
# 11_5 How has it affected technology?
# 11_6 How have the different giants in the business responded to this?
# 11_7 Has its introduction led to increase in business?
# 11_8 If designs are already futuristic, how will this change in the future?
# 12_1 What is a good age to get LASIK?
# 12_2 Give me a short description of the procedure.
# 12_3 What are its benefits?
# 12_4 What are the risks?
# 12_5 Describe experiences of some people who had it done.
# 12_6 Are there any good alternatives to it?
# 12_7 What is its success rate?
# 12_8 Once it's done, what kind of precautions do I need to take?
# 12_9 Does the effect wear off with age?
# 13_1 What is tofu exactly?
# 13_2 How is it made?
# 13_3 What are its origins?
# 13_4 What is the best tofu?
# 13_5 Is it a kind of cheese?
# 13_6 Can I eat it raw?
# 13_7 What are common ways to cook it?
# 13_8 In what cuisines is it popular?
# 13_9 Is tofu good for you?
# 13_10 Can it make you sick?
# 13_11 Is too much tofu bad for you?
# 14_1 What are scalable data center network architectures?
# 14_2 What are some examples?
# 14_3 Describe the characteristics of FAT tree topology.
# 14_4 What routes can be taken by an upstream packet?
# 14_5 Describe core, aggregator and edge switches.
# 14_6 Are flows bidirectional?
# 14_7 How many forwarding rules are there in each layer of the tree?
# 14_8 Describe the jellyfish architecture.
# 14_9 Which architecture is more resilient to failure?
# 15_1 Tell me about the International Linguistics Olympiad.
# 15_2 How do I prepare for it?
# 15_3 How tough is the exam?
# 15_4 What kind of problems can I expect?
# 15_5 Tell me about the history of linguistics as a field.
# 15_6 Who was Panini and what were his contributions?
# 15_7 What is the link between linguistics and computer science?
# 16_1 What is a normal blood sugar level?
# 16_2 What does it mean if it's higher than this?
# 16_3 What is a dangerous level?
# 16_4 How do you bring it down quickly?
# 16_5 How fast can it rise?
# 16_6 And what if it's lower than normal?
# 16_7 How does this make you feel?
# 16_8 Do different activities lead to an imbalance?
# 16_9 Is there a relation between age and sugar levels?
# 17_1 What are the different forms of energy?
# 17_2 How can it be stored?
# 17_3 What type of energy is used in motion?
# 17_4 Tell me about mechanical energy.
# 17_5 Give me some examples.
# 17_6 Why is sound a form of mechanical energy?
# 17_7 How does it differ from potential energy?
# 17_8 Are potential and kinetic the same?
# 17_9 What type does chemical energy belong to?
# 17_10 What form of energy is used in eating?
# 18_1 Describe Uranus.
# 18_2 What makes it so unusual?
# 18_3 Tell me about its orbit.
# 18_4 Why is it tilted?
# 18_5 How is its rotation different from other planets?
# 18_6 What is peculiar about its seasons?
# 18_7 Are there any other planets similar to it?
# 18_8 Describe the characteristics of Neptune.
# 18_9 Why is it important to our solar system?
# 18_10 How are these two planets similar to each other?
# 18_11 Can life exist on either of them?
# 19_1 What is chemical energy?
# 19_2 Describe a chemical reaction.
# 19_3 How is it represented mathematically?
# 19_4 Give me an example.
# 19_5 What are the different kinds of reactions?
# 19_6 What is a decomposition reaction?
# 19_7 How is it a chemical change?
# 19_8 What is a synthesis reaction?
# 19_9 Tell me the differences between synthesis and decomposition.
# 20_1 Describe cell membranes.
# 20_2 What are its important functions?
# 20_3 Tell me about the phospholipid bilayer.
# 20_4 What are its functions?
# 20_5 What if the membrane gets damaged?
# 20_6 Do they repair themselves?
# 20_7 Which nutrients may help in the repair process?
# 21_1 What is weathering?
# 21_2 What are its major types?
# 21_3 Tell me about chemical weathering.
# 21_4 How is it different from biological weathering?
# 21_5 Does it change the composition of rocks?
# 21_6 What is the end product of chemical weathering?
# 21_7 Give me an example.
# 21_8 What happens when quartz undergoes weathering?
# 22_1 What are the most common spices used in cooking?
# 22_2 How are they different from herbs?
# 22_3 Why do spices taste good?
# 22_4 Where do most of them come from?
# 22_5 What cuisines use them heavily?
# 22_6 What are the most popular Indian ones?
# 22_7 Tell me about turmeric.
# 22_8 Are there any benefits of consuming it?
# 22_9 What is the oldest spice?
# 22_10 What is the most expensive and why?
# 23_1 What are the main types of cattle farming?
# 23_2 What breeds produce the most milk?
# 23_3 How much do Holsteins produce?
# 23_4 What is special about Jersey milk?
# 23_5 Do we eat dairy cows?
# 23_6 What are the most common breeds for meat?
# 23_7 Where are angus beef from?
# 23_8 How much space do they need?
# 24_1 How can I help my friend stop smoking?
# 24_2 What are its long term effects?
# 24_3 Does it cause cancer?
# 24_4 What makes it so addictive?
# 24_5 Are there any alternatives to nicotine?
# 24_6 How effective are the patches?
# 24_7 Tell me about the cold turkey method.
# 24_8 Describe typical withdrawal symptoms.
# 25_1 Tell me about Orca whales.
# 25_2 Are they really whales?
# 25_3 How do they hunt?
# 25_4 What do they eat?
# 25_5 Where did they get their name?
# 25_6 Are they dangerous?
# 25_7 Where can go to watch them?
# 25_8 When is a good season for spotting them?
# 25_9 How does captivity affect them?
# 26_1 What defines a chemical element?
# 26_2 How are they related to the Periodic Table?
# 26_3 How is it organised?
# 26_4 How does a chemical compound differ from an element?
# 26_5 What are different types of compounds?
# 26_6 How are they formed?
# 26_7 Which ones are important for the human body?
# 26_8 What are important ones used on a daily basis?
# 27_1 What comprises a balanced diet?
# 27_2 Is it the same for men as well as women?
# 27_3 What are some specific recommendations for women?
# 27_4 Are dairy products necessary for a good health?
# 27_5 Can it harm you instead?
# 27_6 How necessary is fiber?
# 27_7 What happens if it's consumed in a smaller amount than recommended?
# 28_1 Describe global warming.
# 28_2 What are its dangers?
# 28_3 Are there any methods to prevent it getting worse?
# 28_4 What can I do at an individual level?
# 28_5 How do I reduce my carbon footprint?
# 28_6 Is the US government doing anything about it?
# 28_7 How is overpopulation related?
# 29_1 What is the British Invasion in music?
# 29_2 What era did it happen?
# 29_3 What genre did it involve?
# 29_4 What is so special about it?
# 29_5 Which bands were a key part?
# 29_6 What was the leading band and what was its role?
# 29_7 Is it related to any other musical movements?
# 29_8 What was its impact on American music?
# 29_9 What other music movement succeeded it?
# 30_1 What are some advantages of using Linux?
# 30_2 Can I run Windows software in it?
# 30_3 How does it compare to Windows?
# 30_4 Which of these is more popular?
# 30_5 How do I install software on it?
# 30_6 What is an easy way to install Python?
# 30_7 Tell me about how I can share files.

# %% [markdown]
# ## Retrieval
# The ElasticSearchSimpleAPI notebook illustrates how to use ElasticSearch. Use this API to retrieve the top 100 ranked passages for each conversation turn.
#
# To evaluate the results you should use the provided `ConvSearchEvaluation` class. Examine and discuss the recall metric results. In terms of metrics, discuss what should be your goals for each step of the project.

# %%
import TRECCASTeval as trec
import numpy as np
import ElasticSearchSimpleAPI as es

elastic = es.ESSimpleAPI()

test_bed = trec.ConvSearchEvaluation()

for topic in test_bed.train_topics:
    conv_id = topic['number']
    
    for turn in topic['turn']:
        turn_id = turn['number']
        utterance = turn['raw_utterance']
        
        result = elastic.search_body(query = utterance, numDocs = 100)
        topic_turn_id = str(conv_id) + '_' + str(turn_id)
        
        #SE TIVER 0 DOCS RELEVANTES O RECALL DA NAN, ALSO O 1.5 DA ERRO PORQUE SO TEM STOP WORDS- A QUERY SAI VAZIA...
        if (topic_turn_id != "1_5"):
            [p10, recall, ndcg] = test_bed.eval(result[['_id','_score']], topic_turn_id)
            print('topic_turn_id=', topic_turn_id,'P10=', p10, '  Recall=', recall, '  NDCG=',ndcg)        
        
        
#PELO MENOS PARTES SAO REPETIDAS DO EXEMPLO ACIMA, NAO QUERO ALTERAR
# Out:
# topic_turn_id= 1_1 P10= 0.2   Recall= 1.0   NDCG= 0
# topic_turn_id= 1_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 1_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 1_4 P10= 0.0   Recall= 1.0   NDCG= 0
# topic_turn_id= 1_6 P10= 0.2   Recall= 0.875   NDCG= 0
# topic_turn_id= 1_7 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 1_8 P10= 0.0   Recall= 0.25   NDCG= 0
# topic_turn_id= 1_9 P10= 0.1   Recall= 0.26666666666666666   NDCG= 0
# topic_turn_id= 1_10 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 1_11 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 1_12 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 2_1 P10= 0.1   Recall= 1.0   NDCG= 0
# topic_turn_id= 2_2 P10= 0.6   Recall= 0.7142857142857143   NDCG= 0
# topic_turn_id= 2_3 P10= 0.3   Recall= 0.8571428571428571   NDCG= 0
# topic_turn_id= 2_4 P10= 0.1   Recall= 1.0   NDCG= 0
# topic_turn_id= 2_5 P10= 0.8   Recall= 0.9230769230769231   NDCG= 0
# topic_turn_id= 2_6 P10= 0.1   Recall= 0.6666666666666666   NDCG= 0
# topic_turn_id= 2_7 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 2_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 2_9 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 2_10 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 2_11 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 3_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_10 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 3_11 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 4_1 P10= 0.5   Recall= 0.8   NDCG= 0
# topic_turn_id= 4_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_4 P10= 0.2   Recall= 0.6666666666666666   NDCG= 0
# topic_turn_id= 4_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_6 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_7 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_8 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 4_9 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 5_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 5_10 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 6_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 7_1 P10= 0.3   Recall= 1.0   NDCG= 0
# topic_turn_id= 7_2 P10= 0.4   Recall= 1.0   NDCG= 0
# topic_turn_id= 7_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 7_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 7_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 7_6 P10= 0.4   Recall= 0.8   NDCG= 0
# topic_turn_id= 7_7 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 7_8 P10= 0.2   Recall= 1.0   NDCG= 0
# topic_turn_id= 7_9 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 7_10 P10= 0.0   Recall= 0.6666666666666666   NDCG= 0
# topic_turn_id= 7_11 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 8_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 9_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 10_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 11_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 12_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_10 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 13_11 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 14_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 15_1 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 15_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 15_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 15_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 15_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 15_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 15_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 16_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 17_1 P10= 0.3   Recall= 0.8   NDCG= 0
# topic_turn_id= 17_2 P10= 0.0   Recall= 0.625   NDCG= 0
# topic_turn_id= 17_3 P10= 0.5   Recall= 1.0   NDCG= 0
# topic_turn_id= 17_4 P10= 0.9   Recall= 0.9285714285714286   NDCG= 0
# topic_turn_id= 17_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 17_6 P10= 0.5   Recall= 0.9   NDCG= 0
# topic_turn_id= 17_7 P10= 0.0   Recall= 0.5   NDCG= 0
# topic_turn_id= 17_8 P10= 0.5   Recall= 1.0   NDCG= 0
# topic_turn_id= 17_9 P10= 0.5   Recall= 1.0   NDCG= 0
# topic_turn_id= 17_10 P10= 0.1   Recall= 1.0   NDCG= 0
# topic_turn_id= 18_1 P10= 0.5   Recall= 0.8888888888888888   NDCG= 0
# topic_turn_id= 18_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 18_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 18_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 18_5 P10= 0.0   Recall= 1.0   NDCG= 0
# topic_turn_id= 18_6 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 18_7 P10= 0.0   Recall= 0.5   NDCG= 0
# topic_turn_id= 18_8 P10= 0.1   Recall= 0.14285714285714285   NDCG= 0
# topic_turn_id= 18_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 18_10 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 18_11 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 19_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 20_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 21_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 22_1 P10= 0.0   Recall= 0.5   NDCG= 0
# topic_turn_id= 22_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 22_3 P10= 0.1   Recall= 1.0   NDCG= 0
# topic_turn_id= 22_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 22_5 P10= 0.0   Recall= 0.16666666666666666   NDCG= 0
# topic_turn_id= 22_6 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 22_7 P10= 0.0   Recall= 0.8571428571428571   NDCG= 0
# topic_turn_id= 22_8 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 22_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 22_10 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 23_1 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 23_2 P10= 0.0   Recall= 0.25   NDCG= 0
# topic_turn_id= 23_3 P10= 0.7   Recall= 0.9375   NDCG= 0
# topic_turn_id= 23_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 23_5 P10= 0.0   Recall= 1.0   NDCG= 0
# topic_turn_id= 23_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 23_7 P10= 0.3   Recall= 1.0   NDCG= 0
# topic_turn_id= 23_8 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 24_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 24_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 24_3 P10= 0.0   Recall= 0.2222222222222222   NDCG= 0
# topic_turn_id= 24_4 P10= 0.0   Recall= 0.375   NDCG= 0
# topic_turn_id= 24_5 P10= 0.2   Recall= 0.5   NDCG= 0
# topic_turn_id= 24_6 P10= 0.0   Recall= 0.3333333333333333   NDCG= 0
# topic_turn_id= 24_7 P10= 0.0   Recall= 0.5   NDCG= 0
# topic_turn_id= 24_8 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_1 P10= 1.0   Recall= 0.9230769230769231   NDCG= 0
# topic_turn_id= 25_2 P10= 0.0   Recall= 0.36363636363636365   NDCG= 0
# topic_turn_id= 25_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_6 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_7 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_8 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 25_9 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 26_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 26_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 27_1 P10= 0.1   Recall= 0.8888888888888888   NDCG= 0
# topic_turn_id= 27_2 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 27_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 27_4 P10= 0.6   Recall= 0.8333333333333334   NDCG= 0
# topic_turn_id= 27_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 27_6 P10= 0.2   Recall= 0.4   NDCG= 0
# topic_turn_id= 27_7 P10= 0.0   Recall= 1.0   NDCG= 0
# topic_turn_id= 28_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 28_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_1 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_2 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_3 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_4 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_5 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_6 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_7 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_8 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 29_9 P10= 0.0   Recall= nan   NDCG= 0
# topic_turn_id= 30_1 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 30_2 P10= 0.0   Recall= 0.14285714285714285   NDCG= 0
# topic_turn_id= 30_3 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 30_4 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 30_5 P10= 0.0   Recall= 0.0   NDCG= 0
# topic_turn_id= 30_6 P10= 0.2   Recall= 1.0   NDCG= 0
# topic_turn_id= 30_7 P10= 0.1   Recall= 0.6666666666666666   NDCG= 0

# %% [markdown]
# ## Passage Ranking
# The Passage Ranking notebook example illustrates how to use the BERT service to compute the similarity between sentences. Using the BERT service, improve a passage ranking method to rerank the initial retrieval step.
#
# To evaluate the results you should use the provided `ConvSearchEvaluation` class.

# %% [markdown]
# ## Conversation State-Tracking
#
# Conversation State Tracking example ilustrates how to use the
#
# To evaluate the results you should use the provided `ConvSearchEvaluation` class.
